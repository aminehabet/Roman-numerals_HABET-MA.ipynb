# %% [markdown]
# # Roman numerals

# %% [markdown]
# ## I. Roman numerals to decimals
#
# Write a function which receives a Roman numeral written out as a string, and returns an integer representing the decimal form of the input number.

# %%
mapping = {"I" : 1, 
           "V" : 5,
           "X" : 10,
           "L" : 50,
           "C" : 100,
           "D" : 500,
           "M" : 1000}

# %%
def roman_to_decimal(rom):
    l=len(rom)
    somme = 0
    for i in range(l-1):
        if mapping[rom[i+1]] > mapping[rom[i]]:
            somme -= mapping[rom[i]]
        elif mapping[rom[i]] >= mapping[rom[i+1]]:
            somme += mapping[rom[i]]
    somme += mapping[rom[-1]]
    dec = somme
    return dec

# %% [markdown]
# Here are some tests for you to test your code. Your code must pass all of them. You also need to come up with several more tests (your choice).

# %%
test_pairs = [("IX", 9), ("XI", 11), ("MCCII", 1202), ("MMXVIII", 2018), ("XLIX", 49),
              ("XVIIII", 19), ("XIX", 19), ("MCDXLIV", 1444), ("MCMXCIX", 1999)]

for rom, dec in test_pairs:
    converted = roman_to_decimal(rom)
    print(converted == dec)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# Now you can run tests in file `tests_Roman_numerals.txt`. You need to insert a number of false results and listed false results in respective field in Google Form for this lesson.

# %%
p = "C:\\Users\\Lenovo\\Desktop\\home work programming\\test\\tests_Roman_numerals.txt"
with open(p, "rb") as fp:
    lines_roman=fp.readlines()
    print(lines_roman)

test_data_roman = [line.strip().decode("ascii").split(',') for line in lines_roman]
test_data_roman = [(line[0], int(line[1])) for line in test_data_roman]


for rom, dec in test_data_roman:
    converted = roman_to_decimal(rom)
    print(converted == dec)
# Out:
# [b'CCLXXXVII,287\r\n', b'CXIII,113\r\n', b'MDCCCXIII,1813\r\n', b'LXV,65\r\n', b'MDCCLXII,1762\r\n', b'CMLXXIII,973\r\n', b'MDCLXXXV,1685\r\n', b'DCCCXXVI,826\r\n', b'CXLV,145\r\n', b'MDLXXXVII,1587\r\n', b'MCMXCI,1991\r\n', b'LXXIX,79\r\n', b'DCCCLXII,862\r\n', b'MCII,1102\r\n', b'MDCCL,1750\r\n', b'DCCXLI,741\r\n', b'MDCXIII,1613\r\n', b'DLIV,554\r\n', b'MDCCXXXI,1731\r\n', b'LII,52\r\n', b'MCXXI,1121\r\n', b'CDXLVIII,448\r\n', b'MCCXLVIII,1246\r\n', b'LXXIV,74\r\n', b'CCCXVIII,318\r\n', b'XCVIII,98\r\n', b'MCDLXV,1465\r\n', b'DXXXIV,534\r\n', b'DCLIV,654\r\n', b'CLXXIII,173\r\n', b'MCDXLIV,1444\r\n', b'DLXIX,569\r\n', b'DCCLXXI,771\r\n', b'MDXVIII,1518\r\n', b'DCLXVIII,668\r\n', b'CCXCII,292\r\n', b'MDXVI,1516\r\n', b'DCXXXIII,633\r\n', b'DVI,506\r\n', b'CDLXI,461\r\n', b'DCLXXXIII,683\r\n', b'MDCCCLXXIX,1879\r\n', b'MDCCCXXIX,1829\r\n', b'CLXX,170\r\n', b'DCXXXIV,634\r\n', b'DCVI,606\r\n', b'MCCXLVI,1246\r\n', b'DCCXLIII,743\r\n', b'DXXIX,529\r\n', b'CDXCIII,493\r\n', b'DCCCXLVI,846\r\n', b'MDCLIII,1653\r\n', b'CMLV,955\r\n', b'MDCCXIII,1713\r\n', b'CDLXII,462\r\n', b'CCCLI,351\r\n', b'CDXX,420\r\n', b'CMXXXI,931\r\n', b'CCLXXXI,281\r\n', b'CCCIX,309\r\n', b'CCXLIII,243\r\n', b'MCLXXX,1180\r\n', b'MCCLXXXVIII,1288\r\n', b'DCCXI,711\r\n', b'MDXLV,1545\r\n', b'MLXXVIII,1078\r\n', b'CVII,107\r\n', b'MCDXCI,1491\r\n', b'CMXXXIII,933\r\n', b'DCCXXXVI,736\r\n', b'DCCLXXXV,785\r\n', b'D,500\r\n', b'XXXIV,34\r\n', b'DCCXI,711\r\n', b'MDCCCXCIII,1893\r\n', b'MDCCCXCI,1891\r\n', b'MCCCL,1350\r\n', b'DCCCLXXXVIII,888\r\n', b'MDVI,1506\r\n', b'ML,1050\r\n', b'CLXXIX,179\r\n', b'MCMXLI,1941\r\n', b'CCLXXVI,276\r\n', b'MCDLXXV,1475\r\n', b'XCIX,99\r\n', b'CDLXXXVII,487\r\n', b'MXLVI,1046\r\n', b'DCCCXII,812\r\n', b'MDCCLXXXIII,1783\r\n', b'MCCXXVI,1226\r\n', b'CVII,107\r\n', b'DCCLXXXVI,786\r\n', b'MCCLXX,1273\r\n', b'MDCCX,1708\r\n', b'MDLXXXIX,1589\r\n', b'CCCXI,311\r\n', b'LXXI,71\r\n', b'MDLXXXVII,1587\r\n', b'CMXC,990\r\n', b'MDLXXX,1580\r\n', b'CCCXCVIII,398\r\n', b'XLIII,43\r\n', b'CCLXX,270\r\n', b'MDLXXI,1571\r\n', b'DCCI,701\r\n', b'MDCCLXI,1761\r\n', b'MDLXXVI,1576\r\n', b'MCXCIV,1194\r\n', b'MDCCXXIII,1723\r\n', b'MCDXXIX,1429\r\n', b'MXLVI,1046\r\n', b'MDCCXXXVI,1736\r\n', b'MDCCLX,1760\r\n', b'LXVII,67\r\n', b'MCDLXXIII,1473\r\n', b'MCLXI,1161\r\n', b'CCCLXXXIII,383\r\n', b'MDCLXVI,1666\r\n', b'MCLXXXI,1181\r\n', b'CMXLIII,943\r\n', b'CCCLXVI,366\r\n', b'LXXXIX,89\r\n', b'DCCXCII,792\r\n', b'MCCCLXIII,1363\r\n', b'MCMXLII,1942\r\n', b'MCCCLXIII,1363\r\n', b'MCLXI,1161\r\n', b'CCCLIV,354\r\n', b'DCCXIII,713\r\n', b'MDCCCXXIII,1823\r\n', b'DCLXXVII,677\r\n', b'MCCCLXXI,1371\r\n', b'CCCLXIII,363\r\n', b'MDLXXX,1580\r\n', b'MDXLVIII,1548\r\n', b'LXXXIV,81\r\n', b'MDXXXII,1532\r\n', b'CMXXVI,926\r\n', b'CCXLI,241\r\n', b'DCCCXXV,825\r\n', b'MDCLXI,1661\r\n', b'MLXXX,1080\r\n', b'DCCII,702\r\n', b'CCXLVII,247\r\n', b'DCCLXX,770\r\n', b'MCDXXXII,1432\r\n', b'CCCLXX,370\r\n', b'DCCLXXIX,779\r\n', b'DLXX,570\r\n', b'MCCCXLIV,1344\r\n', b'MCCCLXXVIII,1378\r\n', b'DCCCLXI,861\r\n', b'MCMXXV,1925\r\n', b'DCCXXVII,727\r\n', b'XCVI,96\r\n', b'CCXX,220\r\n', b'MCXIX,1119\r\n', b'DCCCXXXVI,836\r\n', b'M,1000\r\n', b'MDXI,1511\r\n', b'MCCCII,1302\r\n', b'CCLIV,254\r\n', b'DCCCXCIV,894\r\n', b'CCXI,211\r\n', b'CDLXI,461\r\n', b'CMXXIX,929\r\n', b'MDCXX,1620\r\n', b'CCII,202\r\n', b'MCXLIV,1144\r\n', b'MDCCCXLII,1842\r\n', b'MXX,1020\r\n', b'MDCCVIII,1708\r\n', b'DCCCXCVII,897\r\n', b'DCCXCVII,799\r\n', b'DCLXXIX,679\r\n', b'CDLXXXV,485\r\n', b'MCCCLXXXI,1381\r\n', b'DCCVII,707\r\n', b'CCCXXXV,335\r\n', b'MDCIII,1603\r\n', b'MCDXCIV,1494\r\n', b'MCCLXXXVII,1287\r\n', b'MCMXLVI,1946\r\n', b'MDIV,1504\r\n', b'CCLXVIII,268\r\n', b'CMLXVIII,968\r\n', b'DCCCXCV,895\r\n', b'MDCCCLXXII,1872\r\n', b'MCXVIII,1118\r\n', b'MCMXXXV,1935\r\n', b'CCXXXIV,234\r\n', b'MCDLV,1455\r\n', b'DCCCLXXXVII,887\r\n', b'CCLXXIII,273\r\n', b'MCCLXXXVI,1286\r\n', b'MCCLXXI,1271\r\n', b'DVIII,508\r\n', b'CXXXII,132\r\n', b'MCDLXI,1461\r\n', b'DCCCI,801\r\n', b'MCMVI,190 ...
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True

# %% [markdown]
# ## II. Decimal numbers to roman numerals.
#
# The maximum grade for first task (Roman to decimal) is 7 on the 10-point HSE scale. For extra credit, complete the second task: *given a decimal number, convert it to the Roman form*.

# %%
def decimal_to_roman(dec):

    roman, dict = "", {1: "I", 5: "V", 10: "X", 50: "L", 100: "C", 500: "D", 1000: "M"}
    values = [1000, 500, 100, 50, 10, 5, 1]
 
    for i, v in enumerate(values):
        if dec // v == 4:
            rom+=dict[values[i]]+dict[values[i-1]]
        elif dec // v > 0:
            rom+=dict[values[i]] * (dec // v)
 
        dec-= dec // v * v
    return rom

# %% [markdown]
# You need to come up with test cases to show that your conversion works as expected.
# NB: the conversion is ambiguous in some cases. Any valid conversion is accepted.

# %% [markdown]
# Now, put false decimal numbers from previous set of tests in ascending order, convert them to Roman numerals and list them in respected field in Google Form for this lesson.

# %%
p = "C:\\Users\\Lenovo\\Desktop\\home work programming\\test\\test_numerals_Roman.txt"
with open(p, "rb") as fp:
    lines_roman=fp.readlines()
    print(lines_roman)
test_data_roman = [line.strip().decode("ascii").split(',') for line in lines_roman]
test_data_roman = [(line[0], int(line[1])) for line in test_data_roman]

for rom, dec in test_data_roman:
    converted = decimal_to_roman(dec)
    print(converted == rom)
# Out:
# [b'1\r\n', b'12\r\n', b'13\r\n', b'50\r\n', b'124\r\n', b'9000\r\n', b'875\r\n']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-dd6b011bd2bc> in <module>
#       4     print(lines_roman)
#       5 test_data_roman = [line.strip().decode("ascii").split(',') for line in lines_roman]
# ----> 6 test_data_roman = [(line[0], int(line[1])) for line in test_data_roman]
#       7
#       8 for rom, dec in test_data_roman:
#
# <ipython-input-43-dd6b011bd2bc> in <listcomp>(.0)
#       4     print(lines_roman)
#       5 test_data_roman = [line.strip().decode("ascii").split(',') for line in lines_roman]
# ----> 6 test_data_roman = [(line[0], int(line[1])) for line in test_data_roman]
#       7
#       8 for rom, dec in test_data_roman:
#
# IndexError: list index out of range
